# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from numpy.random import multinomial

def bootstrap(series, n=1000, *args, **kwargs):
    return multinomial(series.sum(), series/series.sum(), n)

# %%
import numpy as np

from lint.models import Bucket

def plot_bootstrap(token, w=8, h=8):
    
    series = Bucket.token_series(token)
    
    expected = series.sum() / len(series)

    bs = bootstrap(np.full(len(series), expected))
    
    plt.figure(figsize=(w, h))

    plt.plot(bs.mean(0))

    plt.fill_between(
        range(100),
        bs.mean(0) + 2*bs.std(0),
        bs.mean(0) - 2*bs.std(0),
        color='black',
        alpha=0.1,
    )
    
    plt.plot(series)
    
    print(token)
    plt.show()

# %%
from joblib import Memory

from lint.models import Bucket

mem = Memory('cache')

token_counts = mem.cache(Bucket.token_counts)

tokens = token_counts(10000)

# %%
colors = [
    'beige',
    'black',
    'blue',
    'brown',
    'crimson',
    'cyan',
    'gray',
    'grey',
    'green',
    'indigo',
    'magenta',
    'maroon',
    'orange',
    'pink',
    'purple',
    'red',
    'scarlet',
    'tan',
    'teal',
    'turquoise',
    'white',
    'yellow',
]

for color in colors:
    plot_bootstrap(color)
# Out:
# beige
# black
# blue
# brown
# crimson
# cyan
# gray
# grey
# green
# indigo
# magenta
# maroon
# orange
# pink
# purple
# red
# scarlet
# tan
# teal
# turquoise
# white
# yellow

# %%
plot_bootstrap('light')
plot_bootstrap('dark')
# Out:
# light
# dark

# %%
plot_bootstrap('hot')
plot_bootstrap('cold')
# Out:
# hot
# cold

# %%
days = [
    'monday',
    'tuesday',
    'wednesday',
    'thursday',
    'friday',
    'saturday',
    'sunday',
]

for day in days:
    plot_bootstrap(day)
# Out:
# monday
# tuesday
# wednesday
# thursday
# friday
# saturday
# sunday

# %%
meals = ['breakfast', 'lunch', 'dinner', 'supper', 'tea']

for meal in meals:
    plot_bootstrap(meal)
# Out:
# breakfast
# lunch
# dinner
# supper
# tea
