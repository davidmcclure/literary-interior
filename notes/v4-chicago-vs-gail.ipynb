# %% [markdown]
# # Baseline series

# %%
from lint.models import Offset

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
# %matplotlib inline

# %%
chicago = Offset.baseline_series('chicago')
gail = Offset.baseline_series('gail')

f, (ax1, ax2) = plt.subplots(1, 2, sharey=True)

ax1.set_title('Chicago')
ax1.plot(*zip(*chicago.items()))

ax2.set_title('Gail')
ax2.plot(*zip(*gail.items()))

# %% [markdown]
# # Raw token series

# %%
def plot_token_series(token):
    
    chicago = Offset.token_series(token, corpus='chicago')
    gail = Offset.token_series(token, corpus='gail')
    
    print(token)
    
    f, (ax1, ax2) = plt.subplots(1, 2)
    
    plt.title('Offset-binned token counts')
    plt.tight_layout(w_pad=3)

    ax1.set_title('Chicago')
    ax1.plot(*zip(*chicago.items()))

    ax2.set_title('Gail')
    ax2.plot(*zip(*gail.items()))

    plt.show()

# %%
plot_token_series('the')
plot_token_series('him')
plot_token_series('early')
plot_token_series('young')
plot_token_series('old')
plot_token_series('death')
plot_token_series('marriage')
plot_token_series('a')
plot_token_series('an')
# Out:
# the
# him
# early
# young
# old
# death
# marriage
# a
# an

# %%
plot_token_series('love')
plot_token_series('wait')
plot_token_series('think')
plot_token_series('thought')
plot_token_series('feel')
plot_token_series('wonder')
plot_token_series('worry')
plot_token_series('reflect')
plot_token_series('see')
plot_token_series('hear')
plot_token_series('listen')
plot_token_series('guess')
plot_token_series('assume')
plot_token_series('realize')
plot_token_series('fear')
plot_token_series('hope')
plot_token_series('god')
# Out:
# love
# wait
# think
# thought
# feel
# wonder
# worry
# reflect
# see
# hear
# listen
# guess
# assume
# realize
# fear
# hope
# god

# %% [markdown]
# # Raw POS series

# %%
def plot_pos_series(pos):
    
    chicago = Offset.pos_series(pos, corpus='chicago')
    gail = Offset.pos_series(pos, corpus='gail')
    
    print(pos)
    
    f, (ax1, ax2) = plt.subplots(1, 2)
    
    plt.title('Offset-binned token counts')
    plt.tight_layout(w_pad=3)

    ax1.set_title('Chicago')
    ax1.plot(*zip(*chicago.items()))

    ax2.set_title('Gail')
    ax2.plot(*zip(*gail.items()))

    plt.show()

# %%
plot_pos_series('JJ')
plot_pos_series('JJR')
plot_pos_series('JJS')
plot_pos_series('NN')
plot_pos_series('NNS')
plot_pos_series('NNP')
plot_pos_series('NNPS')
plot_pos_series('VB')
plot_pos_series('VBD')
plot_pos_series('VBG')
plot_pos_series('VBN')
plot_pos_series('VBP')
plot_pos_series('VBZ')
plot_pos_series('CD')
# Out:
# JJ
# JJR
# JJS
# NN
# NNS
# NNP
# NNPS
# VB
# VBD
# VBG
# VBN
# VBP
# VBZ
# CD
